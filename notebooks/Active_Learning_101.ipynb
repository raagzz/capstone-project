# %% [markdown]
# <a href="https://colab.research.google.com/github/raagzz/capstone-project/blob/main/Active_Learning_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Installing the Packages
# !pip install git+https://github.com/modAL-python/modAL.git
# Out:
# Collecting git+https://github.com/modAL-python/modAL.git
#   Cloning https://github.com/modAL-python/modAL.git to /tmp/pip-req-build-35y0qfk1
#   Running command git clone --filter=blob:none --quiet https://github.com/modAL-python/modAL.git /tmp/pip-req-build-35y0qfk1
#   Resolved https://github.com/modAL-python/modAL.git to commit bba6f6fd00dbb862b1e09259b78caf6cffa2e755
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from modAL-python==0.4.2) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from modAL-python==0.4.2) (1.5.2)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.10/dist-packages (from modAL-python==0.4.2) (1.13.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from modAL-python==0.4.2) (2.2.2)
# Collecting skorch==0.9.0 (from modAL-python==0.4.2)
#   Downloading skorch-0.9.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from skorch==0.9.0->modAL-python==0.4.2) (0.9.0)
# Requirement already satisfied: tqdm>=4.14.0 in /usr/local/lib/python3.10/dist-packages (from skorch==0.9.0->modAL-python==0.4.2) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->modAL-python==0.4.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->modAL-python==0.4.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->modAL-python==0.4.2) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->modAL-python==0.4.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->modAL-python==0.4.2) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.0->modAL-python==0.4.2) (1.16.0)
# Downloading skorch-0.9.0-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.8/125.8 kB 869.9 kB/s eta 0:00:00
# Building wheels for collected packages: modAL-python
#   Building wheel for modAL-python (setup.py) ... done
#   Created wheel for modAL-python: filename=modAL_python-0.4.2-py3-none-any.whl size=32647 sha256=316478644e24d3dcdac20740b875a40b4c14cf9fd5cf27fa7dde6fbb3b2bf479
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mqjwrcq6/wheels/d9/fb/59/7deb61b460c1c36394cd093758986ff7d36f71352dcb2e02c5
# Successfully built modAL-python
# Installing collected packages: skorch, modAL-python
# Successfully installed modAL-python-0.4.2 skorch-0.9.0

# %% [markdown]
# ### Importing the Required Packages

# %%
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score

from modAL.models import ActiveLearner
from modAL.uncertainty import uncertainty_sampling, entropy_sampling
from modAL.disagreement import vote_entropy_sampling

# %% [markdown]
# ### Generating the Data

# %%
X, y = make_classification(n_samples=5000, n_features=20, n_informative=15, n_classes=2)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# - Here, 100 data points are randomly chosen as the initial labeled dataset, and the model is first trained on this small set.

# %%
### Initial Data For Tarining
initial_idx = np.random.choice(range(len(X_train)), size=100, replace=False)
X_initial, y_initial = X_train[initial_idx], y_train[initial_idx]

# %% [markdown]
# - The remaining data points are treated as an unlabeled pool, from which the model can query new instances

# %%
### Pool Data - Unlabeled
X_pool = np.delete(X_train, initial_idx, axis=0)
y_pool = np.delete(y_train, initial_idx, axis=0)

# %% [markdown]
# ### Define Active Learner
# - Two strategies used in this notebook
#   - Uncertainty Sampling
#   - Entropy Sampling

# %%
### RF with Uncertainty Sampling
learner_uncertainty = ActiveLearner(
    estimator=RandomForestClassifier(),
    query_strategy=uncertainty_sampling,
    X_training=X_initial, y_training=y_initial
)

# %%
### RF with Entropy Sampling
learner_entropy = ActiveLearner(
    estimator=RandomForestClassifier(),
    query_strategy=entropy_sampling,
    X_training=X_initial, y_training=y_initial
)

# %% [markdown]
# ### Active Learning Parameters
# - Number of queries (```n_queries = 50```)
# - Accuracy
# - F1 Score

# %%
### Helper Variables
n_queries = 50
performance_uncertainty = []
performance_entropy = []

# %% [markdown]
# ### Active Learning Loop | Performace Capture
# - Initial Training: The model starts with a small labeled set.
# - Query: The model queries a new, most informative data point from the unlabeled pool (based on stargeies it will change).
# - Label: The oracle provides the label for the queried point.
# - Retraining: The model adds the new data point to its training set and retrains.
# - Evaluation: The model's performance is evaluated after each retraining.
# - Repeat: The process repeats for a predefined number of queries (in the starter notebook, 50 queries).

# %%
def run_active_learning(learner, X_pool, y_pool, strategy_name):
    '''Keeps the loop running and capture the performance of the model'''
    performance = []
    for i in range(n_queries):
        query_idx, _ = learner.query(X_pool)
        learner.teach(X_pool[query_idx], y_pool[query_idx])
        X_pool, y_pool = np.delete(X_pool, query_idx, axis=0), np.delete(y_pool, query_idx, axis=0)
        y_pred = learner.predict(X_test)
        acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        performance.append((acc, f1))
        print(f"{strategy_name} | Query {i+1}: Accuracy = {acc:.4f}, F1-Score = {f1:.4f}")
    return performance

# %% [markdown]
# ### Run active learning and store performance

# %%
performance_uncertainty = run_active_learning(learner_uncertainty, X_pool.copy(), y_pool.copy(), "Uncertainty Sampling")
performance_entropy = run_active_learning(learner_entropy, X_pool.copy(), y_pool.copy(), "Entropy Sampling")
# Out:
# Uncertainty Sampling | Query 1: Accuracy = 0.8420, F1-Score = 0.8458
# Uncertainty Sampling | Query 2: Accuracy = 0.8413, F1-Score = 0.8470
# Uncertainty Sampling | Query 3: Accuracy = 0.8460, F1-Score = 0.8522
# Uncertainty Sampling | Query 4: Accuracy = 0.8413, F1-Score = 0.8463
# Uncertainty Sampling | Query 5: Accuracy = 0.8493, F1-Score = 0.8551
# Uncertainty Sampling | Query 6: Accuracy = 0.8333, F1-Score = 0.8383
# Uncertainty Sampling | Query 7: Accuracy = 0.8460, F1-Score = 0.8513
# Uncertainty Sampling | Query 8: Accuracy = 0.8593, F1-Score = 0.8643
# Uncertainty Sampling | Query 9: Accuracy = 0.8553, F1-Score = 0.8608
# Uncertainty Sampling | Query 10: Accuracy = 0.8513, F1-Score = 0.8542
# Uncertainty Sampling | Query 11: Accuracy = 0.8520, F1-Score = 0.8557
# Uncertainty Sampling | Query 12: Accuracy = 0.8447, F1-Score = 0.8482
# Uncertainty Sampling | Query 13: Accuracy = 0.8393, F1-Score = 0.8397
# Uncertainty Sampling | Query 14: Accuracy = 0.8520, F1-Score = 0.8526
# Uncertainty Sampling | Query 15: Accuracy = 0.8567, F1-Score = 0.8575
# Uncertainty Sampling | Query 16: Accuracy = 0.8547, F1-Score = 0.8581
# Uncertainty Sampling | Query 17: Accuracy = 0.8433, F1-Score = 0.8432
# Uncertainty Sampling | Query 18: Accuracy = 0.8560, F1-Score = 0.8596
# Uncertainty Sampling | Query 19: Accuracy = 0.8500, F1-Score = 0.8542
# Uncertainty Sampling | Query 20: Accuracy = 0.8553, F1-Score = 0.8583
# Uncertainty Sampling | Query 21: Accuracy = 0.8380, F1-Score = 0.8383
# Uncertainty Sampling | Query 22: Accuracy = 0.8480, F1-Score = 0.8488
# Uncertainty Sampling | Query 23: Accuracy = 0.8373, F1-Score = 0.8399
# Uncertainty Sampling | Query 24: Accuracy = 0.8527, F1-Score = 0.8541
# Uncertainty Sampling | Query 25: Accuracy = 0.8587, F1-Score = 0.8598
# Uncertainty Sampling | Query 26: Accuracy = 0.8540, F1-Score = 0.8545
# Uncertainty Sampling | Query 27: Accuracy = 0.8460, F1-Score = 0.8479
# Uncertainty Sampling | Query 28: Accuracy = 0.8493, F1-Score = 0.8483
# Uncertainty Sampling | Query 29: Accuracy = 0.8547, F1-Score = 0.8551
# Uncertainty Sampling | Query 30: Accuracy = 0.8447, F1-Score = 0.8460
# Uncertainty Sampling | Query 31: Accuracy = 0.8540, F1-Score = 0.8553
# Uncertainty Sampling | Query 32: Accuracy = 0.8493, F1-Score = 0.8507
# Uncertainty Sampling | Query 33: Accuracy = 0.8553, F1-Score = 0.8575
# Uncertainty Sampling | Query 34: Accuracy = 0.8540, F1-Score = 0.8535
# Uncertainty Sampling | Query 35: Accuracy = 0.8513, F1-Score = 0.8526
# Uncertainty Sampling | Query 36: Accuracy = 0.8507, F1-Score = 0.8517
# Uncertainty Sampling | Query 37: Accuracy = 0.8433, F1-Score = 0.8465
# Uncertainty Sampling | Query 38: Accuracy = 0.8533, F1-Score = 0.8547
# Uncertainty Sampling | Query 39: Accuracy = 0.8613, F1-Score = 0.8615
# Uncertainty Sampling | Query 40: Accuracy = 0.8547, F1-Score = 0.8552
# Uncertainty Sampling | Query 41: Accuracy = 0.8473, F1-Score = 0.8478
# Uncertainty Sampling | Query 42: Accuracy = 0.8540, F1-Score = 0.8549
# Uncertainty Sampling | Query 43: Accuracy = 0.8693, F1-Score = 0.8704
# Uncertainty Sampling | Query 44: Accuracy = 0.8573, F1-Score = 0.8596
# Uncertainty Sampling | Query 45: Accuracy = 0.8747, F1-Score = 0.8784
# Uncertainty Sampling | Query 46: Accuracy = 0.8727, F1-Score = 0.8724
# Uncertainty Sampling | Query 47: Accuracy = 0.8747, F1-Score = 0.8763
# Uncertainty Sampling | Query 48: Accuracy = 0.8733, F1-Score = 0.8738
# Uncertainty Sampling | Query 49: Accuracy = 0.8633, F1-Score = 0.8638
# Uncertainty Sampling | Query 50: Accuracy = 0.8747, F1-Score = 0.8766
# Entropy Sampling | Query 1: Accuracy = 0.8507, F1-Score = 0.8547
# Entropy Sampling | Query 2: Accuracy = 0.8460, F1-Score = 0.8511
# Entropy Sampling | Query 3: Accuracy = 0.8407, F1-Score = 0.8437
# Entropy Sampling | Query 4: Accuracy = 0.8460, F1-Score = 0.8524
# Entropy Sampling | Query 5: Accuracy = 0.8467, F1-Score = 0.8535
# Entropy Sampling | Query 6: Accuracy = 0.8533, F1-Score = 0.8564
# Entropy Sampling | Query 7: Accuracy = 0.8540, F1-Score = 0.8595
# Entropy Sampling | Query 8: Accuracy = 0.8613, F1-Score = 0.8649
# Entropy Sampling | Query 9: Accuracy = 0.8513, F1-Score = 0.8540
# Entropy Sampling | Query 10: Accuracy = 0.8500, F1-Score = 0.8557
# Entropy Sampling | Query 11: Accuracy = 0.8593, F1-Score = 0.8618
# Entropy Sampling | Query 12: Accuracy = 0.8580, F1-Score = 0.8623
# Entropy Sampling | Query 13: Accuracy = 0.8500, F1-Score = 0.8532
# Entropy Sampling | Query 14: Accuracy = 0.8447, F1-Score = 0.8496
# Entropy Sampling | Query 15: Accuracy = 0.8620, F1-Score = 0.8660
# Entropy Sampling | Query 16: Accuracy = 0.8533, F1-Score = 0.8551
# Entropy Sampling | Query 17: Accuracy = 0.8633, F1-Score = 0.8685
# Entropy Sampling | Query 18: Accuracy = 0.8613, F1-Score = 0.8656
# Entropy Sampling | Query 19: Accuracy = 0.8647, F1-Score = 0.8686
# Entropy Sampling | Query 20: Accuracy = 0.8613, F1-Score = 0.8642
# Entropy Sampling | Query 21: Accuracy = 0.8587, F1-Score = 0.8632
# Entropy Sampling | Query 22: Accuracy = 0.8653, F1-Score = 0.8678
# Entropy Sampling | Query 23: Accuracy = 0.8593, F1-Score = 0.8591
# Entropy Sampling | Query 24: Accuracy = 0.8607, F1-Score = 0.8622
# Entropy Sampling | Query 25: Accuracy = 0.8693, F1-Score = 0.8712
# Entropy Sampling | Query 26: Accuracy = 0.8580, F1-Score = 0.8609
# Entropy Sampling | Query 27: Accuracy = 0.8673, F1-Score = 0.8683
# Entropy Sampling | Query 28: Accuracy = 0.8660, F1-Score = 0.8673
# Entropy Sampling | Query 29: Accuracy = 0.8740, F1-Score = 0.8732
# Entropy Sampling | Query 30: Accuracy = 0.8720, F1-Score = 0.8706
# Entropy Sampling | Query 31: Accuracy = 0.8660, F1-Score = 0.8684
# Entropy Sampling | Query 32: Accuracy = 0.8587, F1-Score = 0.8605
# Entropy Sampling | Query 33: Accuracy = 0.8553, F1-Score = 0.8583
# Entropy Sampling | Query 34: Accuracy = 0.8700, F1-Score = 0.8736
# Entropy Sampling | Query 35: Accuracy = 0.8687, F1-Score = 0.8696
# Entropy Sampling | Query 36: Accuracy = 0.8613, F1-Score = 0.8658
# Entropy Sampling | Query 37: Accuracy = 0.8687, F1-Score = 0.8712
# Entropy Sampling | Query 38: Accuracy = 0.8653, F1-Score = 0.8664
# Entropy Sampling | Query 39: Accuracy = 0.8620, F1-Score = 0.8658
# Entropy Sampling | Query 40: Accuracy = 0.8707, F1-Score = 0.8719
# Entropy Sampling | Query 41: Accuracy = 0.8633, F1-Score = 0.8654
# Entropy Sampling | Query 42: Accuracy = 0.8627, F1-Score = 0.8650
# Entropy Sampling | Query 43: Accuracy = 0.8633, F1-Score = 0.8670
# Entropy Sampling | Query 44: Accuracy = 0.8593, F1-Score = 0.8620
# Entropy Sampling | Query 45: Accuracy = 0.8687, F1-Score = 0.8694
# Entropy Sampling | Query 46: Accuracy = 0.8720, F1-Score = 0.8727
# Entropy Sampling | Query 47: Accuracy = 0.8607, F1-Score = 0.8604
# Entropy Sampling | Query 48: Accuracy = 0.8753, F1-Score = 0.8739
# Entropy Sampling | Query 49: Accuracy = 0.8680, F1-Score = 0.8675
# Entropy Sampling | Query 50: Accuracy = 0.8700, F1-Score = 0.8699

# %% [markdown]
# ### Helper Steps for Plotting

# %%
acc_uncertainty, f1_uncertainty = zip(*performance_uncertainty)
acc_entropy, f1_entropy = zip(*performance_entropy)
sns.set(style="whitegrid")

# %% [markdown]
# ### Plotting the Performance over the queries

# %%
plt.plot(range(1, n_queries + 1), acc_uncertainty, label='Uncertainty Sampling', marker='o')
plt.plot(range(1, n_queries + 1), acc_entropy, label='Entropy Sampling', marker='s')
plt.title("Accuracy over Queries")
plt.xlabel("Query Iteration")
plt.ylabel("Accuracy")
plt.legend()

# %%
plt.plot(range(1, n_queries + 1), f1_uncertainty, label='Uncertainty Sampling', marker='o')
plt.plot(range(1, n_queries + 1), f1_entropy, label='Entropy Sampling', marker='s')
plt.title("F1-Score over Queries")
plt.xlabel("Query Iteration")
plt.ylabel("F1-Score")
# Out:
# Text(0, 0.5, 'F1-Score')
