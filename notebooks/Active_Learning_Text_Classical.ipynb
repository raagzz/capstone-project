# %%
# !pip install modal-python
# Out:
# Requirement already satisfied: modal-python in /usr/local/lib/python3.10/dist-packages (0.4.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from modal-python) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from modal-python) (1.5.2)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.10/dist-packages (from modal-python) (1.13.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from modal-python) (2.2.2)
# Requirement already satisfied: skorch==0.9.0 in /usr/local/lib/python3.10/dist-packages (from modal-python) (0.9.0)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from skorch==0.9.0->modal-python) (0.9.0)
# Requirement already satisfied: tqdm>=4.14.0 in /usr/local/lib/python3.10/dist-packages (from skorch==0.9.0->modal-python) (4.66.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->modal-python) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->modal-python) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->modal-python) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->modal-python) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->modal-python) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.0->modal-python) (1.16.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score

from modAL.models import ActiveLearner,Committee
from modAL.uncertainty import uncertainty_sampling, entropy_sampling,margin_sampling

from keras.datasets import imdb

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=10000)

# %%
word_index = imdb.get_word_index()
index_word = {value: key for (key, value) in word_index.items()}

# %%
def decode_review(review):
    return " ".join([index_word.get(i - 3, "?") for i in review])

# %%
X_train_text = [decode_review(review) for review in X_train]
X_test_text = [decode_review(review) for review in X_test]

# %%
vectorizer = TfidfVectorizer(max_features=10000)
X_train_tfidf = vectorizer.fit_transform(X_train_text)
X_test_tfidf = vectorizer.transform(X_test_text)

# %%
initial_idx = np.random.choice(range(X_train_tfidf.shape[0]), size=100, replace=False)
X_initial, y_initial = X_train_tfidf[initial_idx], y_train[initial_idx]

# %%
X_pool = np.delete(X_train_tfidf.toarray(), initial_idx, axis=0)
y_pool = np.delete(y_train, initial_idx, axis=0)

# %%
def random_sampling(learner, X_pool, n_samples=1):
    ''' Randomly selects n_samples from X_pool '''
    n_pool = len(X_pool)
    query_idx = np.random.choice(range(n_pool), size=n_samples, replace=False)
    return query_idx, X_pool[query_idx]

# %%
learner_random = ActiveLearner(
    estimator=SVC(probability=True),
    query_strategy=random_sampling,
    X_training=X_initial, y_training=y_initial
)

# %%
# Naive Bayes with Uncertainty Sampling
learner_uncertainty = ActiveLearner(
    estimator=SVC(probability=True),
    query_strategy=uncertainty_sampling,
    X_training=X_initial,
    y_training=y_initial,
)

# %%
# Naive Bayes with Entropy Sampling
learner_entropy = ActiveLearner(
    estimator=SVC(probability=True),
    query_strategy=entropy_sampling,
    X_training=X_initial,
    y_training=y_initial,
)

# %%
# Naive Bayes with Margin Sampling
learner_margin = ActiveLearner(
    estimator=SVC(probability=True),
    query_strategy=margin_sampling,
    X_training=X_initial,
    y_training=y_initial,
)

# %%
n_queries = 50
performance_random = []
performance_uncertainty = []
performance_entropy = []
performance_margin = []

# %%
def run_active_learning(learner, X_pool, y_pool, strategy_name):
    """Keeps the loop running and capture the performance of the model"""
    performance = []
    for i in range(n_queries):
        query_idx, _ = learner.query(X_pool)
        learner.teach(X_pool[query_idx], y_pool[query_idx])
        X_pool, y_pool = np.delete(X_pool, query_idx, axis=0), np.delete(
            y_pool, query_idx, axis=0
        )
        y_pred = learner.predict(X_test_tfidf)
        acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        performance.append((acc, f1))
        print(
            f"{strategy_name} | Query {i+1}: Accuracy = {acc:.4f}, F1-Score = {f1:.4f}"
        )
    return performance

# %%
for strategy, learner in zip(
    ["Random Sampling","Uncertainty Sampling", "Entropy Sampling", "Margin Sampling"],
    [learner_random, learner_uncertainty, learner_entropy, learner_margin],
):
    # Reset the pools for each learner
    X_pool = np.delete(X_train_tfidf.toarray(), initial_idx, axis=0)
    y_pool = np.delete(y_train, initial_idx, axis=0)

    # Run active learning
    performance = run_active_learning(learner, X_pool.copy(), y_pool.copy(), strategy)

    if strategy == "Random Sampling":
        performance_random = performance
    elif strategy == "Uncertainty Sampling":
        performance_uncertainty = performance
    elif strategy == "Entropy Sampling":
        performance_entropy = performance
    elif strategy == "Margin Sampling":
        performance_margin = performance
# Out:
# Random Sampling | Query 1: Accuracy = 0.5942, F1-Score = 0.7038
# Random Sampling | Query 2: Accuracy = 0.6202, F1-Score = 0.7122
# Random Sampling | Query 3: Accuracy = 0.5955, F1-Score = 0.7043
# Random Sampling | Query 4: Accuracy = 0.6188, F1-Score = 0.7112
# Random Sampling | Query 5: Accuracy = 0.6574, F1-Score = 0.7201
# Random Sampling | Query 6: Accuracy = 0.6189, F1-Score = 0.7129
# Random Sampling | Query 7: Accuracy = 0.6598, F1-Score = 0.7227
# Random Sampling | Query 8: Accuracy = 0.6228, F1-Score = 0.7130
# Random Sampling | Query 9: Accuracy = 0.6590, F1-Score = 0.7221
# Random Sampling | Query 10: Accuracy = 0.6248, F1-Score = 0.7145
# Random Sampling | Query 11: Accuracy = 0.5966, F1-Score = 0.7049
# Random Sampling | Query 12: Accuracy = 0.5775, F1-Score = 0.6984
# Random Sampling | Query 13: Accuracy = 0.5948, F1-Score = 0.7046
# Random Sampling | Query 14: Accuracy = 0.6212, F1-Score = 0.7146
# Random Sampling | Query 15: Accuracy = 0.6610, F1-Score = 0.7250
# Random Sampling | Query 16: Accuracy = 0.6165, F1-Score = 0.7131
# Random Sampling | Query 17: Accuracy = 0.5894, F1-Score = 0.7035
# Random Sampling | Query 18: Accuracy = 0.6128, F1-Score = 0.7121
# Random Sampling | Query 19: Accuracy = 0.5953, F1-Score = 0.7060
# Random Sampling | Query 20: Accuracy = 0.5739, F1-Score = 0.6977
# Random Sampling | Query 21: Accuracy = 0.5969, F1-Score = 0.7060
# Random Sampling | Query 22: Accuracy = 0.6267, F1-Score = 0.7150
# Random Sampling | Query 23: Accuracy = 0.6041, F1-Score = 0.7078
# Random Sampling | Query 24: Accuracy = 0.5937, F1-Score = 0.7046
# Random Sampling | Query 25: Accuracy = 0.5774, F1-Score = 0.6982
# Random Sampling | Query 26: Accuracy = 0.5630, F1-Score = 0.6926
# Random Sampling | Query 27: Accuracy = 0.5563, F1-Score = 0.6903
# Random Sampling | Query 28: Accuracy = 0.5443, F1-Score = 0.6853
# Random Sampling | Query 29: Accuracy = 0.5500, F1-Score = 0.6877
# Random Sampling | Query 30: Accuracy = 0.5607, F1-Score = 0.6921
# Random Sampling | Query 31: Accuracy = 0.5792, F1-Score = 0.6993
# Random Sampling | Query 32: Accuracy = 0.5658, F1-Score = 0.6940
# Random Sampling | Query 33: Accuracy = 0.5554, F1-Score = 0.6899
# Random Sampling | Query 34: Accuracy = 0.5683, F1-Score = 0.6949
# Random Sampling | Query 35: Accuracy = 0.5881, F1-Score = 0.7026
# Random Sampling | Query 36: Accuracy = 0.5740, F1-Score = 0.6972
# Random Sampling | Query 37: Accuracy = 0.5596, F1-Score = 0.6914
# Random Sampling | Query 38: Accuracy = 0.5530, F1-Score = 0.6890
# Random Sampling | Query 39: Accuracy = 0.5609, F1-Score = 0.6920
# Random Sampling | Query 40: Accuracy = 0.5514, F1-Score = 0.6882
# Random Sampling | Query 41: Accuracy = 0.5690, F1-Score = 0.6947
# Random Sampling | Query 42: Accuracy = 0.5854, F1-Score = 0.7011
# Random Sampling | Query 43: Accuracy = 0.6062, F1-Score = 0.7092
# Random Sampling | Query 44: Accuracy = 0.5931, F1-Score = 0.7042
# Random Sampling | Query 45: Accuracy = 0.5863, F1-Score = 0.7018
# Random Sampling | Query 46: Accuracy = 0.5809, F1-Score = 0.6995
# Random Sampling | Query 47: Accuracy = 0.5736, F1-Score = 0.6965
# Random Sampling | Query 48: Accuracy = 0.5920, F1-Score = 0.7040
# Random Sampling | Query 49: Accuracy = 0.5845, F1-Score = 0.7007
# Random Sampling | Query 50: Accuracy = 0.5761, F1-Score = 0.6975
# Uncertainty Sampling | Query 1: Accuracy = 0.5921, F1-Score = 0.7025
# Uncertainty Sampling | Query 2: Accuracy = 0.6168, F1-Score = 0.7095
# Uncertainty Sampling | Query 3: Accuracy = 0.5916, F1-Score = 0.7028
# Uncertainty Sampling | Query 4: Accuracy = 0.5760, F1-Score = 0.6972
# Uncertainty Sampling | Query 5: Accuracy = 0.5964, F1-Score = 0.7054
# Uncertainty Sampling | Query 6: Accuracy = 0.5711, F1-Score = 0.6958
# Uncertainty Sampling | Query 7: Accuracy = 0.5873, F1-Score = 0.7022
# Uncertainty Sampling | Query 8: Accuracy = 0.6179, F1-Score = 0.7141
# Uncertainty Sampling | Query 9: Accuracy = 0.6570, F1-Score = 0.7275
# Uncertainty Sampling | Query 10: Accuracy = 0.7006, F1-Score = 0.7298
# Uncertainty Sampling | Query 11: Accuracy = 0.6861, F1-Score = 0.6216
# Uncertainty Sampling | Query 12: Accuracy = 0.7062, F1-Score = 0.7345
# Uncertainty Sampling | Query 13: Accuracy = 0.6916, F1-Score = 0.6264
# Uncertainty Sampling | Query 14: Accuracy = 0.6134, F1-Score = 0.4056
# Uncertainty Sampling | Query 15: Accuracy = 0.5718, F1-Score = 0.2718
# Uncertainty Sampling | Query 16: Accuracy = 0.6306, F1-Score = 0.4568
# Uncertainty Sampling | Query 17: Accuracy = 0.5877, F1-Score = 0.3240
# Uncertainty Sampling | Query 18: Accuracy = 0.6430, F1-Score = 0.4914
# Uncertainty Sampling | Query 19: Accuracy = 0.6024, F1-Score = 0.3703
# Uncertainty Sampling | Query 20: Accuracy = 0.6563, F1-Score = 0.5315
# Uncertainty Sampling | Query 21: Accuracy = 0.7034, F1-Score = 0.6726
# Uncertainty Sampling | Query 22: Accuracy = 0.6617, F1-Score = 0.5534
# Uncertainty Sampling | Query 23: Accuracy = 0.7062, F1-Score = 0.6760
# Uncertainty Sampling | Query 24: Accuracy = 0.7124, F1-Score = 0.7292
# Uncertainty Sampling | Query 25: Accuracy = 0.7058, F1-Score = 0.6736
# Uncertainty Sampling | Query 26: Accuracy = 0.7134, F1-Score = 0.7298
# Uncertainty Sampling | Query 27: Accuracy = 0.6990, F1-Score = 0.7410
# Uncertainty Sampling | Query 28: Accuracy = 0.7147, F1-Score = 0.7307
# Uncertainty Sampling | Query 29: Accuracy = 0.7137, F1-Score = 0.6906
# Uncertainty Sampling | Query 30: Accuracy = 0.6782, F1-Score = 0.5905
# Uncertainty Sampling | Query 31: Accuracy = 0.7168, F1-Score = 0.6976
# Uncertainty Sampling | Query 32: Accuracy = 0.6816, F1-Score = 0.6003
# Uncertainty Sampling | Query 33: Accuracy = 0.7164, F1-Score = 0.6994
# Uncertainty Sampling | Query 34: Accuracy = 0.6811, F1-Score = 0.6014
# Uncertainty Sampling | Query 35: Accuracy = 0.7191, F1-Score = 0.7055
# Uncertainty Sampling | Query 36: Accuracy = 0.7148, F1-Score = 0.7345
# Uncertainty Sampling | Query 37: Accuracy = 0.7189, F1-Score = 0.7032
# Uncertainty Sampling | Query 38: Accuracy = 0.7181, F1-Score = 0.7379
# Uncertainty Sampling | Query 39: Accuracy = 0.7063, F1-Score = 0.7468
# Uncertainty Sampling | Query 40: Accuracy = 0.6873, F1-Score = 0.7449
# Uncertainty Sampling | Query 41: Accuracy = 0.6605, F1-Score = 0.7372
# Uncertainty Sampling | Query 42: Accuracy = 0.6838, F1-Score = 0.7463
# Uncertainty Sampling | Query 43: Accuracy = 0.7095, F1-Score = 0.7531
# Uncertainty Sampling | Query 44: Accuracy = 0.7283, F1-Score = 0.7485
# Uncertainty Sampling | Query 45: Accuracy = 0.7318, F1-Score = 0.7209
# Uncertainty Sampling | Query 46: Accuracy = 0.7311, F1-Score = 0.7494
# Uncertainty Sampling | Query 47: Accuracy = 0.7298, F1-Score = 0.7161
# Uncertainty Sampling | Query 48: Accuracy = 0.7018, F1-Score = 0.6426
# Uncertainty Sampling | Query 49: Accuracy = 0.7306, F1-Score = 0.7182
# Uncertainty Sampling | Query 50: Accuracy = 0.7352, F1-Score = 0.7558
# Entropy Sampling | Query 1: Accuracy = 0.5880, F1-Score = 0.7019
# Entropy Sampling | Query 2: Accuracy = 0.6015, F1-Score = 0.7070
# Entropy Sampling | Query 3: Accuracy = 0.6314, F1-Score = 0.7160
# Entropy Sampling | Query 4: Accuracy = 0.6645, F1-Score = 0.7214
# Entropy Sampling | Query 5: Accuracy = 0.6881, F1-Score = 0.6980
# Entropy Sampling | Query 6: Accuracy = 0.6661, F1-Score = 0.7228
# Entropy Sampling | Query 7: Accuracy = 0.6917, F1-Score = 0.7089
# Entropy Sampling | Query 8: Accuracy = 0.6716, F1-Score = 0.7271
# Entropy Sampling | Query 9: Accuracy = 0.6983, F1-Score = 0.7164
# Entropy Sampling | Query 10: Accuracy = 0.6725, F1-Score = 0.7273
# Entropy Sampling | Query 11: Accuracy = 0.6958, F1-Score = 0.7162
# Entropy Sampling | Query 12: Accuracy = 0.6854, F1-Score = 0.6323
# Entropy Sampling | Query 13: Accuracy = 0.6457, F1-Score = 0.5191
# Entropy Sampling | Query 14: Accuracy = 0.6976, F1-Score = 0.6660
# Entropy Sampling | Query 15: Accuracy = 0.6968, F1-Score = 0.7227
# Entropy Sampling | Query 16: Accuracy = 0.7038, F1-Score = 0.6759
# Entropy Sampling | Query 17: Accuracy = 0.6965, F1-Score = 0.7248
# Entropy Sampling | Query 18: Accuracy = 0.7034, F1-Score = 0.6840
# Entropy Sampling | Query 19: Accuracy = 0.6590, F1-Score = 0.5526
# Entropy Sampling | Query 20: Accuracy = 0.7013, F1-Score = 0.6777
# Entropy Sampling | Query 21: Accuracy = 0.6958, F1-Score = 0.7164
# Entropy Sampling | Query 22: Accuracy = 0.6986, F1-Score = 0.6753
# Entropy Sampling | Query 23: Accuracy = 0.6621, F1-Score = 0.5598
# Entropy Sampling | Query 24: Accuracy = 0.7021, F1-Score = 0.6818
# Entropy Sampling | Query 25: Accuracy = 0.6954, F1-Score = 0.7181
# Entropy Sampling | Query 26: Accuracy = 0.7056, F1-Score = 0.6885
# Entropy Sampling | Query 27: Accuracy = 0.6708, F1-Score = 0.5817
# Entropy Sampling | Query 28: Accuracy = 0.6292, F1-Score = 0.4591
# Entropy Sampling | Query 29: Accuracy = 0.6096, F1-Score = 0.3982
# Entropy Sampling | Query 30: Accuracy = 0.5776, F1-Score = 0.2905
# Entropy Sampling | Query 31: Accuracy = 0.5550, F1-Score = 0.2135
# Entropy Sampling | Query 32: Accuracy = 0.5764, F1-Score = 0.2879
# Entropy Sampling | Query 33: Accuracy = 0.6105, F1-Score = 0.3984
# Entropy Sampling | Query 34: Accuracy = 0.6472, F1-Score = 0.5073
# Entropy Sampling | Query 35: Accuracy = 0.6916, F1-Score = 0.6314
# Entropy Sampling | Query 36: Accuracy = 0.7128, F1-Score = 0.7060
# Entropy Sampling | Query 37: Accuracy = 0.6944, F1-Score = 0.6391
# Entropy Sampling | Query 38: Accuracy = 0.7170, F1-Score = 0.7085
# Entropy Sampling | Query 39: Accuracy = 0.7109, F1-Score = 0.7226
# Entropy Sampling | Query 40: Accuracy = 0.7128, F1-Score = 0.6933
# Entropy Sampling | Query 41: Accuracy = 0.7124, F1-Score = 0.7235
# Entropy Sampling | Query 42: Accuracy = 0.7159, F1-Score = 0.7019
# Entropy Sampling | Query 43: Accuracy = 0.6972, F1-Score = 0.6438
# Entropy Sampling | Query 44: Accuracy = 0.7172, F1-Score = 0.7030
# Entropy Sampling | Query 45: Accuracy = 0.6966, F1-Score = 0.6406
# Entropy Sampling | Query 46: Accuracy = 0.7127, F1-Score = 0.6947
# Entropy Sampling | Query 47: Accuracy = 0.7137, F1-Score = 0.7231
# Entropy Sampling | Query 48: Accuracy = 0.7122, F1-Score = 0.6948
# Entropy Sampling | Query 49: Accuracy = 0.7153, F1-Score = 0.7245
# Entropy Sampling | Query 50: Accuracy = 0.7198, F1-Score = 0.7044
# Margin Sampling | Query 1: Accuracy = 0.5574, F1-Score = 0.6897
# Margin Sampling | Query 2: Accuracy = 0.5817, F1-Score = 0.6994
# Margin Sampling | Query 3: Accuracy = 0.6124, F1-Score = 0.7116
# Margin Sampling | Query 4: Accuracy = 0.6424, F1-Score = 0.7198
# Margin Sampling | Query 5: Accuracy = 0.6122, F1-Score = 0.7117
# Margin Sampling | Query 6: Accuracy = 0.6418, F1-Score = 0.7201
# Margin Sampling | Query 7: Accuracy = 0.6732, F1-Score = 0.7233
# Margin Sampling | Query 8: Accuracy = 0.6964, F1-Score = 0.7067
# Margin Sampling | Query 9: Accuracy = 0.6705, F1-Score = 0.5935
# Margin Sampling | Query 10: Accuracy = 0.7003, F1-Score = 0.7137
# Margin Sampling | Query 11: Accuracy = 0.6790, F1-Score = 0.6165
# Margin Sampling | Query 12: Accuracy = 0.6260, F1-Score = 0.4552
# Margin Sampling | Query 13: Accuracy = 0.6846, F1-Score = 0.6351
# Margin Sampling | Query 14: Accuracy = 0.6995, F1-Score = 0.7103
# Margin Sampling | Query 15: Accuracy = 0.6806, F1-Score = 0.7263
# Margin Sampling | Query 16: Accuracy = 0.7007, F1-Score = 0.7157
# Margin Sampling | Query 17: Accuracy = 0.6926, F1-Score = 0.6489
# Margin Sampling | Query 18: Accuracy = 0.7014, F1-Score = 0.7170
# Margin Sampling | Query 19: Accuracy = 0.6941, F1-Score = 0.6561
# Margin Sampling | Query 20: Accuracy = 0.6507, F1-Score = 0.5266
# Margin Sampling | Query 21: Accuracy = 0.6140, F1-Score = 0.4110
# Margin Sampling | Query 22: Accuracy = 0.6570, F1-Score = 0.5412
# Margin Sampling | Query 23: Accuracy = 0.7044, F1-Score = 0.6702
# Margin Sampling | Query 24: Accuracy = 0.7119, F1-Score = 0.7283
# Margin Sampling | Query 25: Accuracy = 0.7099, F1-Score = 0.6754
# Margin Sampling | Query 26: Accuracy = 0.7134, F1-Score = 0.7300
# Margin Sampling | Query 27: Accuracy = 0.6970, F1-Score = 0.7410
# Margin Sampling | Query 28: Accuracy = 0.6693, F1-Score = 0.7354
# Margin Sampling | Query 29: Accuracy = 0.7012, F1-Score = 0.7442
# Margin Sampling | Query 30: Accuracy = 0.7168, F1-Score = 0.7347
# Margin Sampling | Query 31: Accuracy = 0.7157, F1-Score = 0.6923
# Margin Sampling | Query 32: Accuracy = 0.6808, F1-Score = 0.5965
# Margin Sampling | Query 33: Accuracy = 0.7132, F1-Score = 0.6896
# Margin Sampling | Query 34: Accuracy = 0.7134, F1-Score = 0.7326
# Margin Sampling | Query 35: Accuracy = 0.6966, F1-Score = 0.7393
# Margin Sampling | Query 36: Accuracy = 0.7149, F1-Score = 0.7337
# Margin Sampling | Query 37: Accuracy = 0.7180, F1-Score = 0.6994
# Margin Sampling | Query 38: Accuracy = 0.6896, F1-Score = 0.6216
# Margin Sampling | Query 39: Accuracy = 0.7158, F1-Score = 0.6970
# Margin Sampling | Query 40: Accuracy = 0.6926, F1-Score = 0.6271
# Margin Sampling | Query 41: Accuracy = 0.7178, F1-Score = 0.6993
# Margin Sampling | Query 42: Accuracy = 0.7192, F1-Score = 0.7379
# Margin Sampling | Query 43: Accuracy = 0.7022, F1-Score = 0.7472
# Margin Sampling | Query 44: Accuracy = 0.7210, F1-Score = 0.7418
# Margin Sampling | Query 45: Accuracy = 0.7276, F1-Score = 0.7174
# Margin Sampling | Query 46: Accuracy = 0.7281, F1-Score = 0.7494
# Margin Sampling | Query 47: Accuracy = 0.7317, F1-Score = 0.7236
# Margin Sampling | Query 48: Accuracy = 0.7268, F1-Score = 0.7476
# Margin Sampling | Query 49: Accuracy = 0.7075, F1-Score = 0.7502
# Margin Sampling | Query 50: Accuracy = 0.7269, F1-Score = 0.7448

# %%
acc_random, f1_random = zip(*performance_random)
acc_uncertainty, f1_uncertainty = zip(*performance_uncertainty)
acc_entropy, f1_entropy = zip(*performance_entropy)
acc_margin, f1_margin = zip(*performance_margin)

# %%
plt.plot(range(1, n_queries + 1), acc_random, label="Random Sampling", color='black', linestyle='--')
plt.plot(range(1, n_queries + 1), acc_uncertainty, label="Uncertainty Sampling")
plt.plot(range(1, n_queries + 1), acc_entropy, label="Entropy Sampling")
plt.plot(range(1, n_queries + 1), acc_margin, label="Margin Sampling")
plt.title("Accuracy over Queries")
plt.xlabel("Query Iteration")
plt.ylabel("Accuracy")
plt.grid(False)
plt.legend()

# %%
plt.plot(range(1, n_queries + 1), np.array(acc_uncertainty) - np.array(acc_random), label="Uncertainty Sampling")
plt.plot(range(1, n_queries + 1), np.array(acc_entropy) - np.array(acc_random), label="Entropy Sampling")
plt.plot(range(1, n_queries + 1), np.array(acc_margin) - np.array(acc_random), label="Margin Sampling")
plt.title("Accuracy Delta over Queries")
plt.xlabel("Query Iteration")
plt.ylabel("Accuracy Delta")
plt.axhline(y=0, color='black', linestyle='--')
plt.grid(False)
plt.legend()

# %%
plt.plot(range(1, n_queries + 1), f1_uncertainty, label="Uncertainty Sampling")
plt.plot(range(1, n_queries + 1), f1_entropy, label="Entropy Sampling")
plt.plot(range(1, n_queries + 1), f1_margin, label="Margin Sampling")
plt.plot(range(1, n_queries + 1), f1_random, label="Random Sampling", color='black', linestyle='--')
plt.title("F1 Score over Queries")
plt.xlabel("Query Iteration")
plt.ylabel("F1 Score")
plt.grid(False)
plt.legend()

# %%
plt.plot(range(1, n_queries + 1), np.array(f1_uncertainty) - np.array(f1_random), label="Uncertainty Sampling")
plt.plot(range(1, n_queries + 1), np.array(f1_entropy) - np.array(f1_random), label="Entropy Sampling")
plt.plot(range(1, n_queries + 1), np.array(f1_margin) - np.array(f1_random), label="Margin Sampling")
plt.title("F1 Score Delta over Queries")
plt.xlabel("Query Iteration")
plt.ylabel("F1 Delta")
plt.axhline(y=0, color='black', linestyle='--')
plt.grid(False)
plt.legend()
